# %%
import pandas as pd
import numpy as np 
import io
import re
import requests
import json
from flask import jsonify, Flask
from urllib.request import urlopen
# import finnhub
# import seaborn as sns
# from word2number import w2n
# import matplotlib.pyplot as plt
import string

# %%
path ="data/minfac_latinAmerica_canada.csv"
df = pd.read_csv(path,encoding='latin1')

# %%
 df.head()
# Out:
#    position  rec_id  year    country commodity  \
# 0         1       1  2007  Australia   Alumina
# 1         2       2  2007  Australia   Alumina
# 2         3       3  2007  Australia   Alumina
# 3         4       4  2007  Australia   Alumina
# 4         5       5  2007  Australia   Alumina
#
#                                             location  \
# 0                              Gladstone, Queensland
# 1                Nhulunbuy, Gove, Northern Territory
# 2  20 kilometers northwest of Collie, Western Aus...
# 3                        Pinjarra, Western Australia
# 4                         Waroona, Western Australia
#
#                      fac_name fac_type      dmslat      dmslong  ...  \
# 0  Gladstone alumina refinery    Plant  24° 09'  S  151° 13'  E  ...
# 1       Gove alumina refinery    Plant  13° 48'  S  136° 44'  E  ...
# 2    Worsley alumina refinery    Plant  34° 46'  S  116° 04'  E  ...
# 3   Pinjarra alumina refinery    Plant  33° 22'  S  115° 55'  E  ...
# 4    Wagerup alumina refinery    Plant  33° 05'  S  115° 55'  E  ...
#
#    precision   mm                             op_comp  \
# 0          F  NaN   Queensland Alumina Ltd., operator
# 1          F  NaN                Alcan Gove Pty. Ltd.
# 2          F  NaN  Worsley Alumina Pty. Ltd., manager
# 3          F  NaN       Alcoa World Alumina Australia
# 4          F  NaN       Alcoa World Alumina Australia
#
#                             maininvest  \
# 0                 Rio Tinto Alcan, 80%
# 1                  Rio Tinto plc, 100%
# 2               BHP Billiton Ltd., 86%
# 3  Alcoa World Alumina Australia, 100%
# 4   Alcoa World Alumina Australia, 60%
#
#                                            othinvest  status capacity  \
# 0                                         Rusal, 20%  Active     3850
# 1                                                NaN  Active     3800
# 2  Japan Alumina Associates (Australia) Pty. Ltd....  Active     3700
# 3                                                NaN  Active     3400
# 4                          Western Mining Corp., 40%  Active     2600
#
#                            units notes cite
# 0  thousand metric tons per year   NaN  847
# 1  thousand metric tons per year   NaN  847
# 2  thousand metric tons per year   NaN  847
# 3  thousand metric tons per year   NaN  847
# 4  thousand metric tons per year   NaN  847
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['position', 'rec_id', 'year', 'country', 'commodity', 'location',
#        'fac_name', 'fac_type', 'dmslat', 'dmslong', 'latitude', 'longitude',
#        'precision', 'mm', 'op_comp', 'maininvest', 'othinvest', 'status',
#        'capacity', 'units', 'notes', 'cite'],
#       dtype='object')

# %%
df.country.value_counts()
# Out:
# Russia               343
# Australia            296
# China                250
# Iran                 229
# Germany              212
#                     ...
# French Guiana          1
# Domincan Republic      1
# Burkina Faso           1
# Western Sahara         1
# Liberia                1
# Name: country, Length: 167, dtype: int64

# %%
df.commodity.value_counts()
# Out:
# Cement                                        570
# cement                                        207
# Iron and steel: crude steel                   203
# Gold                                          188
# Petroleum: crude                              159
#                                              ...
# Ferroalloys: ferromanganese, blast furnace      1
# Fertilizer: apatite, gross weight               1
# red granite                                     1
# Iron and steel: stainless steel                 1
# columbium (tantalum)                            1
# Name: commodity, Length: 670, dtype: int64

# %%
df['commodity']= df['commodity'].str.lower()

# %%
df.commodity.value_counts()
# Out:
# cement                           777
# gold                             289
# iron and steel: crude steel      203
# copper                           168
# aluminum                         162
#                                 ...
# iron and steel: pipe steel         1
# columbium (niobium), tantalum      1
# labradorite                        1
# cement (clinker)                   1
# barite-zinc                        1
# Name: commodity, Length: 595, dtype: int64

# %%
drop_df = df.drop(columns=['fac_type', 'precision', 'mm', 'op_comp', 'othinvest', 'notes', 'cite'])

# %%
drop_df.head(5)
# Out:
#    position  rec_id  year    country commodity  \
# 0         1       1  2007  Australia   alumina
# 1         2       2  2007  Australia   alumina
# 2         3       3  2007  Australia   alumina
# 3         4       4  2007  Australia   alumina
# 4         5       5  2007  Australia   alumina
#
#                                             location  \
# 0                              Gladstone, Queensland
# 1                Nhulunbuy, Gove, Northern Territory
# 2  20 kilometers northwest of Collie, Western Aus...
# 3                        Pinjarra, Western Australia
# 4                         Waroona, Western Australia
#
#                      fac_name      dmslat      dmslong  latitude  longitude  \
# 0  Gladstone alumina refinery  24° 09'  S  151° 13'  E    -23.85     151.22
# 1       Gove alumina refinery  13° 48'  S  136° 44'  E    -12.20     136.73
# 2    Worsley alumina refinery  34° 46'  S  116° 04'  E    -33.24     116.07
# 3   Pinjarra alumina refinery  33° 22'  S  115° 55'  E    -32.64     115.92
# 4    Wagerup alumina refinery  33° 05'  S  115° 55'  E    -32.92     115.91
#
#                             maininvest  status capacity  \
# 0                 Rio Tinto Alcan, 80%  Active     3850
# 1                  Rio Tinto plc, 100%  Active     3800
# 2               BHP Billiton Ltd., 86%  Active     3700
# 3  Alcoa World Alumina Australia, 100%  Active     3400
# 4   Alcoa World Alumina Australia, 60%  Active     2600
#
#                            units
# 0  thousand metric tons per year
# 1  thousand metric tons per year
# 2  thousand metric tons per year
# 3  thousand metric tons per year
# 4  thousand metric tons per year

# %%
drop_df['maininvest'] = drop_df['maininvest'].str.replace(',', '').str.replace('.', '').str.replace('\d+', '').str.replace("%","")
# Out:
# <ipython-input-17-522b7d137ed0>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   drop_df['maininvest'] = drop_df['maininvest'].str.replace(',', '').str.replace('.', '').str.replace('\d+', '').str.replace("%","")
# <ipython-input-17-522b7d137ed0>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   drop_df['maininvest'] = drop_df['maininvest'].str.replace(',', '').str.replace('.', '').str.replace('\d+', '').str.replace("%","")

# %%
drop_df.head()
# Out:
#    position  rec_id  year    country commodity  \
# 0         1       1  2007  Australia   alumina
# 1         2       2  2007  Australia   alumina
# 2         3       3  2007  Australia   alumina
# 3         4       4  2007  Australia   alumina
# 4         5       5  2007  Australia   alumina
#
#                                             location  \
# 0                              Gladstone, Queensland
# 1                Nhulunbuy, Gove, Northern Territory
# 2  20 kilometers northwest of Collie, Western Aus...
# 3                        Pinjarra, Western Australia
# 4                         Waroona, Western Australia
#
#                      fac_name      dmslat      dmslong  latitude  longitude  \
# 0  Gladstone alumina refinery  24° 09'  S  151° 13'  E    -23.85     151.22
# 1       Gove alumina refinery  13° 48'  S  136° 44'  E    -12.20     136.73
# 2    Worsley alumina refinery  34° 46'  S  116° 04'  E    -33.24     116.07
# 3   Pinjarra alumina refinery  33° 22'  S  115° 55'  E    -32.64     115.92
# 4    Wagerup alumina refinery  33° 05'  S  115° 55'  E    -32.92     115.91
#
#                        maininvest  status capacity  \
# 0                Rio Tinto Alcan   Active     3850
# 1                  Rio Tinto plc   Active     3800
# 2               BHP Billiton Ltd   Active     3700
# 3  Alcoa World Alumina Australia   Active     3400
# 4  Alcoa World Alumina Australia   Active     2600
#
#                            units
# 0  thousand metric tons per year
# 1  thousand metric tons per year
# 2  thousand metric tons per year
# 3  thousand metric tons per year
# 4  thousand metric tons per year

# %%
drop_df['commodity']= df['commodity'].str.lower()

# %%
df = drop_df

# %%
df.head()
# Out:
#    position  rec_id  year    country commodity  \
# 0         1       1  2007  Australia   alumina
# 1         2       2  2007  Australia   alumina
# 2         3       3  2007  Australia   alumina
# 3         4       4  2007  Australia   alumina
# 4         5       5  2007  Australia   alumina
#
#                                             location  \
# 0                              Gladstone, Queensland
# 1                Nhulunbuy, Gove, Northern Territory
# 2  20 kilometers northwest of Collie, Western Aus...
# 3                        Pinjarra, Western Australia
# 4                         Waroona, Western Australia
#
#                      fac_name      dmslat      dmslong  latitude  longitude  \
# 0  Gladstone alumina refinery  24° 09'  S  151° 13'  E    -23.85     151.22
# 1       Gove alumina refinery  13° 48'  S  136° 44'  E    -12.20     136.73
# 2    Worsley alumina refinery  34° 46'  S  116° 04'  E    -33.24     116.07
# 3   Pinjarra alumina refinery  33° 22'  S  115° 55'  E    -32.64     115.92
# 4    Wagerup alumina refinery  33° 05'  S  115° 55'  E    -32.92     115.91
#
#                        maininvest  status capacity  \
# 0                Rio Tinto Alcan   Active     3850
# 1                  Rio Tinto plc   Active     3800
# 2               BHP Billiton Ltd   Active     3700
# 3  Alcoa World Alumina Australia   Active     3400
# 4  Alcoa World Alumina Australia   Active     2600
#
#                            units
# 0  thousand metric tons per year
# 1  thousand metric tons per year
# 2  thousand metric tons per year
# 3  thousand metric tons per year
# 4  thousand metric tons per year

# %%
df.to_csv('clean_data.csv', index=False, header=True)

# %%
path2 ="data/Electric_Vehicle_Population_Data.csv"
df2 = pd.read_csv(path2)

# %%
df2.head()
# Out:
#    VIN (1-10)     County        City State  ZIP Code  Model Year    Make  \
# 0  1N4BZ0CP4G       King      VASHON    WA     98070        2016  NISSAN
# 1  1N4BZ0CP4G  Snohomish  MILL CREEK    WA     98012        2016  NISSAN
# 2  1N4AZ0CP7D       King     SEATTLE    WA     98115        2013  NISSAN
# 3  1N4BZ0CP5G       King     REDMOND    WA     98053        2016  NISSAN
# 4  1N4BZ0CP1H     Pierce      TACOMA    WA     98403        2017  NISSAN
#
#   Model           Electric Vehicle Type  \
# 0  LEAF  Battery Electric Vehicle (BEV)
# 1  LEAF  Battery Electric Vehicle (BEV)
# 2  LEAF  Battery Electric Vehicle (BEV)
# 3  LEAF  Battery Electric Vehicle (BEV)
# 4  LEAF  Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible              84
# 1           Clean Alternative Fuel Vehicle Eligible              84
# 2           Clean Alternative Fuel Vehicle Eligible              75
# 3           Clean Alternative Fuel Vehicle Eligible              84
# 4           Clean Alternative Fuel Vehicle Eligible             107
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0      29010                  34.0       150297220
# 1      29010                  44.0       157035826
# 2      28800                  46.0       172368493
# 3      29010                  45.0       209103016
# 4      30680                  27.0       193838172
#
#                         Vehicle Location
# 0          POINT (-122.469161 47.415443)
# 1  POINT (-122.20151499999999 47.843376)
# 2          POINT (-122.297534 47.685291)
# 3          POINT (-122.024951 47.670286)
# 4  POINT (-122.45971600000001 47.265523)

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
# reflect an existing database into a new model
Base = automap_base()

# create engine to postgres
engine = create_engine('postgresql://d_knowles:postgres@localhost:5432/sample_db')

# reflect the table
Base.prepare(engine, reflect=True)

# %%
df.to_sql('global_commodities', engine)

# %%
df.to_sql('global_commodities', con=engine, if_exists='replace', index = False)

# %%
df
# Out:
#       position  rec_id  year         country       commodity  \
# 0            1       1  2007       Australia         alumina
# 1            2       2  2007       Australia         alumina
# 2            3       3  2007       Australia         alumina
# 3            4       4  2007       Australia         alumina
# 4            5       5  2007       Australia         alumina
# ...        ...     ...   ...             ...             ...
# 6473      1589    6616  2003        Zimbabwe             tin
# 6474      1590    6617  2003        Zimbabwe           steel
# 6475      1591    6618  2003        Zimbabwe     vermiculite
# 6476      1592    6619  2003        Zimbabwe     vermiculite
# 6477      1593    6620  2003  Western Sahara  phosphate rock
#
#                                                location  \
# 0                                 Gladstone, Queensland
# 1                   Nhulunbuy, Gove, Northern Territory
# 2     20 kilometers northwest of Collie, Western Aus...
# 3                           Pinjarra, Western Australia
# 4                            Waroona, Western Australia
# ...                                                 ...
# 6473                                           Kamativi
# 6474                                           Redcliff
# 6475                                    Dinidza, Dorowa
# 6476                                              Shawa
# 6477                                            Bu Craa
#
#                         fac_name       dmslat       dmslong  latitude  \
# 0     Gladstone alumina refinery   24° 09'  S   151° 13'  E   -23.850
# 1          Gove alumina refinery   13° 48'  S   136° 44'  E   -12.200
# 2       Worsley alumina refinery   34° 46'  S   116° 04'  E   -33.240
# 3      Pinjarra alumina refinery   33° 22'  S   115° 55'  E   -32.640
# 4       Wagerup alumina refinery   33° 05'  S   115° 55'  E   -32.920
# ...                          ...          ...           ...       ...
# 6473                         NaN          NaN           NaN   -18.320
# 6474                         NaN          NaN           NaN   -19.017
# 6475                         NaN          NaN           NaN   -19.217
# 6476                         NaN          NaN           NaN   -19.200
# 6477                         NaN  26° 16' 60"  12° 46' 0" W    26.283
#
#       longitude                      maininvest  status   capacity  \
# 0       151.220                Rio Tinto Alcan   Active       3850
# 1       136.730                  Rio Tinto plc   Active       3800
# 2       116.070               BHP Billiton Ltd   Active       3700
# 3       115.920  Alcoa World Alumina Australia   Active       3400
# 4       115.910  Alcoa World Alumina Australia   Active       2600
# ...         ...                             ...     ...        ...
# 6473     27.070                             NaN  active      1,000
# 6474     29.758                             NaN  active  1,000,000
# 6475     31.717                             NaN  active     40,000
# 6476     31.717                             NaN  active     40,000
# 6477    -12.767                             NaN  active        NaN
#
#                               units
# 0     thousand metric tons per year
# 1     thousand metric tons per year
# 2     thousand metric tons per year
# 3     thousand metric tons per year
# 4     thousand metric tons per year
# ...                             ...
# 6473                         t / yr
# 6474                         t / yr
# 6475                         t / yr
# 6476                         t / yr
# 6477                         t / yr
#
# [6478 rows x 15 columns]
