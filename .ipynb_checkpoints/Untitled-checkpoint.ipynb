# %%
import pandas as pd
import numpy as np 
import re
import requests
import json

from urllib.request import urlopen
import seaborn as sns
from word2number import w2n
import matplotlib.pyplot as plt
import string
import time
import yfinance as yf
import os
import csv

# %%
  from flatten_json import flatten
# Opening JSON file
df = pd.read_csv('/Users/petebaker/Desktop/nest_set.csv',)
  
# returns JSON object as 
# a dictionary

# Iterating through the json
# list

# %%
df =df.reset_index()

# %%
meta_data = pd.DataFrame(data)
meta_data
# Out:
#                                              Company  \
# 0  {'0': 'Rio Tinto PLC', '1': 'Rio Tinto Ltd', '...
#
#                                             Industry  \
# 0  {'0': 'Other Industrial Metals & Mining', '1':...
#
#                                               Ticker  \
# 0  {'0': 'BUE:RIO', '1': 'ASX:RIO', '2': 'XBRU:RI...
#
#                                              Holders
# 0  {'0': {'Holder': {'0': 'Fisher Asset Managemen...

# %%
Company = meta_data['Company']
company =Company[0]

Industry = meta_data['Industry']
Industry = Industry[0]

Ticker = meta_data['Ticker']
Ticker = Ticker[0]

Holders = meta_data['Holders']
Holders = Holders[0]

# %%
meta.__setitem__('Industry',Industry)

# %%
meta.__setitem__('Ticker',Ticker)
meta.__setitem__('Holders',Holders)

# %%
meat= meta.to_dict()

# %%
meat =flatten(meat)

# %%
# Out:
# {'0': 'Rio Tinto PLC',
#  '1': 'Rio Tinto Ltd',
#  '2': 'Rio Tinto PLC',
#  '3': 'Rio Tinto PLC',
#  '4': 'Rio Tinto Ltd',
#  '5': 'Rio Tinto PLC',
#  '6': 'Rio Tinto Ltd',
#  '7': 'Rio Tinto PLC',
#  '8': 'Rio Tinto PLC',
#  '9': 'Rio Tinto Ltd',
#  '10': 'Rio Tinto Ltd',
#  '11': 'Rio Tinto PLC',
#  '12': 'Rio Tinto Ltd',
#  '13': 'Rio Tinto PLC',
#  '14': 'Rio Tinto PLC',
#  '15': 'Rio Tinto PLC',
#  '16': 'Rio Tinto PLC',
#  '17': 'Rio Tinto PLC',
#  '18': 'Rio Tinto PLC',
#  '19': 'Rio Tinto PLC',
#  '20': 'Xstrata PLC',
#  '21': 'Xstrata PLC',
#  '22': 'Xstrata PLC',
#  '23': 'Idemitsu Kosan Co Ltd',
#  '24': 'Idemitsu Kosan Co Ltd',
#  '25': 'Idemitsu Kosan Co Ltd',
#  '26': 'Idemitsu Kosan Co Ltd',
#  '27': 'Idemitsu Kosan Co Ltd',
#  '28': 'Wesfarmers Ltd',
#  '29': 'Wesfarmers Ltd',
#  '30': 'Wesfarmers Ltd',
#  '31': 'Wesfarmers Ltd',
#  '32': 'Wesfarmers Ltd',
#  '33': 'Wesfarmers Ltd',
#  '34': 'Wesfarmers Ltd',
#  '35': 'Wesfarmers Ltd',
#  '36': 'Anglo American PLC',
# ...

# %%
new_df = json.dumps(meat, indent =4)

# %%
new_df
# Out:
# '{\n    "0": "Rio Tinto PLC",\n    "1": "Rio Tinto Ltd",\n    "2": "Rio Tinto PLC",\n    "3": "Rio Tinto PLC",\n    "4": "Rio Tinto Ltd",\n    "5": "Rio Tinto PLC",\n    "6": "Rio Tinto Ltd",\n    "7": "Rio Tinto PLC",\n    "8": "Rio Tinto PLC",\n    "9": "Rio Tinto Ltd",\n    "10": "Rio Tinto Ltd",\n    "11": "Rio Tinto PLC",\n    "12": "Rio Tinto Ltd",\n    "13": "Rio Tinto PLC",\n    "14": "Rio Tinto PLC",\n    "15": "Rio Tinto PLC",\n    "16": "Rio Tinto PLC",\n    "17": "Rio Tinto PLC",\n    "18": "Rio Tinto PLC",\n    "19": "Rio Tinto PLC",\n    "20": "Xstrata PLC",\n    "21": "Xstrata PLC",\n    "22": "Xstrata PLC",\n    "23": "Idemitsu Kosan Co Ltd",\n    "24": "Idemitsu Kosan Co Ltd",\n    "25": "Idemitsu Kosan Co Ltd",\n    "26": "Idemitsu Kosan Co Ltd",\n    "27": "Idemitsu Kosan Co Ltd",\n    "28": "Wesfarmers Ltd",\n    "29": "Wesfarmers Ltd",\n    "30": "Wesfarmers Ltd",\n    "31": "Wesfarmers Ltd",\n    "32": "Wesfarmers Ltd",\n    "33": "Wesfarmers Ltd",\n    "34": "W
# ...

# %%
with open('/Users/petebaker/Desktop/flat_data.json','w') as outfile:
    json.dump(meat, outfile)

# %%
test = {"1":'value', "2":'value2', "3":'value3', "2_1":'value_', "2_2":'value_2', "2_3":'value_3'}

# %%
nest_test = {"1":{"2_1":"value_"}, "2":{"2_2":"value_2"}, "2_3":"value_3"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-89dbe9219593> in <module>
#       1 for t in test:
# ----> 2     print(t["1"])
#
# TypeError: string indices must be integers

# %%
i = 0
j = 1
while i < len(meat):
    new_dic = {}
    for value in meat:
        if meat[i] != meat[j]
            new_dic.update(meat[i])
# Out:
#   File "<ipython-input-110-fb79437fc67d>", line 6
#     if meat[i] != meat[j]
#                          ^
# SyntaxError: invalid syntax

# %%
Holders
# Out:
# {'0': {'Holder': {'0': 'Fisher Asset Management, LLC',
#    '1': 'State Farm Mutual Automobile Insurance Co',
#    '2': 'Franklin Resources, Inc.',
#    '3': 'Arrowstreet Capital, Limited Partnership',
#    '4': 'Goldman Sachs Group, Inc.',
#    '5': 'Dimensional Fund Advisors LP',
#    '6': 'Harding Loevner LLC',
#    '7': 'Capital International Investors',
#    '8': 'Neuberger Berman Group, LLC',
#    '9': 'Earnest Partners LLC'},
#   'Shares': {'0': 12165772,
#    '1': 12132020,
#    '2': 10511419,
#    '3': 6328480,
#    '4': 5303810,
#    '5': 3141974,
#    '6': 2755692,
#    '7': 2686989,
#    '8': 1922463,
#    '9': 1773479},
#   'Date Reported': {'0': 1609286400000,
#    '1': 1609286400000,
#    '2': 1609286400000,
#    '3': 1609286400000,
#    '4': 1609286400000,
#    '5': 1609286400000,
#    '6': 1609286400000,
#    '7': 1609286400000,
#    '8': 1609286400000,
#    '9': 1609286400000},
#   '% Out': {'0': 0.0098,
#    '1': 0.0097,
#    '2': 0.0084,
#    '3': 0.0051,
# ...

# %%
meta_data
# Out:
#                                              Company  \
# 0  {'0': 'Rio Tinto PLC', '1': 'Rio Tinto Ltd', '...
#
#                                             Industry  \
# 0  {'0': 'Other Industrial Metals & Mining', '1':...
#
#                                               Ticker  \
# 0  {'0': 'BUE:RIO', '1': 'ASX:RIO', '2': 'XBRU:RI...
#
#                                              Holders
# 0  {'0': {'Holder': {'0': 'Fisher Asset Managemen...

# %%
comp =pd.DataFrame(company, index=[0])

# %%
comp.to_csv(r'/Users/petebaker/Desktop/comp_nest.csv')

# %%
industry = pd.DataFrame(Industry, index=[0])
industry.to_csv(r'/Users/petebaker/Desktop/industry_nest.csv')

# %%
tick = pd.DataFrame(Ticker, index=[0])
tick.to_csv(r'/Users/petebaker/Desktop/tick_nest.csv')

# %%
hold = pd.DataFrame(Holders)
hold.to_csv(r'/Users/petebaker/Desktop/hold_nest.csv')

# %%
hold
# Out:
#                                                                0  \
# Holder         {'0': 'Fisher Asset Management, LLC', '1': 'St...
# Shares         {'0': 12165772, '1': 12132020, '2': 10511419, ...
# Date Reported  {'0': 1609286400000, '1': 1609286400000, '2': ...
# % Out          {'0': 0.0098, '1': 0.0097, '2': 0.0084, '3': 0...
# Value          {'0': 915109369, '1': 912570544, '2': 79066893...
# 0                                                            NaN
# 1                                                            NaN
#
#                                                                1     2     3  \
# Holder         {'0': 'Fisher Asset Management, LLC', '1': 'St...  None  None
# Shares         {'0': 12165772, '1': 12132020, '2': 10511419, ...  None  None
# Date Reported  {'0': 1609286400000, '1': 1609286400000, '2': ...  None  None
# % Out          {'0': 0.0098, '1': 0.0097, '2': 0.0084, '3': 0...  None  None
# ...

# %%
result = df.to_json(orient='split')

# %%
with open('/Users/petebaker/Desktop/comp_nest.json', 'w') as outfile:
    json.dump(data, outfile)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-183-3c505dfad916> in <module>
#       1 with open('/Users/petebaker/Desktop/comp_nest.json', 'w') as outfile:
# ----> 2     json.dump(data, outfile)
#
# ~/anaconda3/lib/python3.8/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# ~/anaconda3/lib/python3.8/json/encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
# ...

# %%
result
# Out:
# '{"columns":["Company","index","Rio Tinto PLC","Rio Tinto Ltd","Rio Tinto PLC.1","Rio Tinto PLC.2","Rio Tinto Ltd.1","Rio Tinto PLC.3","Rio Tinto Ltd.2","Rio Tinto PLC.4","Rio Tinto PLC.5","Rio Tinto Ltd.3","Rio Tinto Ltd.4","Rio Tinto PLC.6","Rio Tinto Ltd.5","Rio Tinto PLC.7","Rio Tinto PLC.8","Rio Tinto PLC.9","Rio Tinto PLC.10","Rio Tinto PLC.11","Rio Tinto PLC.12","Rio Tinto PLC.13","Xstrata PLC","Xstrata PLC.1","Xstrata PLC.2","Idemitsu Kosan Co Ltd","Idemitsu Kosan Co Ltd.1","Idemitsu Kosan Co Ltd.2","Idemitsu Kosan Co Ltd.3","Idemitsu Kosan Co Ltd.4","Wesfarmers Ltd","Wesfarmers Ltd.1","Wesfarmers Ltd.2","Wesfarmers Ltd.3","Wesfarmers Ltd.4","Wesfarmers Ltd.5","Wesfarmers Ltd.6","Wesfarmers Ltd.7","Anglo American PLC","Anglo American PLC.1","Anglo American PLC.2","Anglo American PLC.3","Anglo American PLC.4","Anglo American PLC.5","Anglo American PLC.6","Anglo American PLC.7","Anglo American PLC.8","Anglo American PLC.9","Anglo American PLC.10","Anglo American PLC.11","Anglo 
# ...

# %%
df.to_json(r'/Users/petebaker/Desktop/comp_index.json')

# %%
df
# Out:
#          Company                                      Rio Tinto PLC  \
# 0       Industry                   Other Industrial Metals & Mining
# 1          Stock                                            BUE:RIO
# 2         Holder  {'0': 'Fisher Asset Management, LLC', '1': 'St...
# 3         Shares  {'0': 12165772, '1': 12132020, '2': 10511419, ...
# 4  Date Reported  {'0': 1609286400000, '1': 1609286400000, '2': ...
# 5          % Out  {'0': 0.0098, '1': 0.0097, '2': 0.0084, '3': 0...
# 6          Value  {'0': 915109369, '1': 912570544, '2': 79066893...
#
#                                        Rio Tinto Ltd  \
# 0                   Other Industrial Metals & Mining
# 1                                            ASX:RIO
# 2  {'0': 'Fisher Asset Management, LLC', '1': 'St...
# 3  {'0': 12165772, '1': 12132020, '2': 10511419, ...
# 4  {'0': 1609286400000, '1': 1609286400000, '2': ...
# 5  {'0': 0.0098, '1': 0.0097, '2': 0.0084, '3': 0...
# ...
