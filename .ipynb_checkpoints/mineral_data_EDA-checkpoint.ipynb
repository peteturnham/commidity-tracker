# %%
#dependencies
import pandas as pd
import numpy as np 
import re
import requests
import json
from flask import jsonify, Flask
from urllib.request import urlopen
import seaborn as sns
from word2number import w2n
import matplotlib.pyplot as plt
import string
import time
import yfinance as yf
import os
import csv

# %%
#read in our data
path ="/Users/petebaker/Downloads/minfac.csv"
ev_path = "/Users/petebaker/Downloads/Electric_Vehicle_Population_Data.csv"
df = pd.read_csv(path,encoding='latin1')
ev_df = pd.read_csv(ev_path)

# %%
#normalize commodities
df['commodity'] = df['commodity'].str.lower()

# %%
#removing characters from maininvest column
df['maininvest'] = df['maininvest'].str.replace(',', '')\
.str.replace('.', '')\
.str.replace('\d+', '')\
.str.replace("%","")\
.str.replace(";","")\
.str.replace("Ltd","")\
.str.replace("plc","")\
.str.replace("pty","")\
.str.replace("pty","")

# %%
df['Holders'] = df_stocks
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-169-accae3db5146> in <module>
# ----> 1 df['Holders'] = df_stocks
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3762
#    3763             # turn me into an ndarray
# ...

# %%
df
# Out:
#       position  rec_id  year         country       commodity  \
# 0            1       1  2007       Australia         Alumina
# 1            2       2  2007       Australia         Alumina
# 2            3       3  2007       Australia         Alumina
# 3            4       4  2007       Australia         Alumina
# 4            5       5  2007       Australia         Alumina
# ...        ...     ...   ...             ...             ...
# 6473      1589    6616  2003        Zimbabwe             tin
# 6474      1590    6617  2003        Zimbabwe           Steel
# 6475      1591    6618  2003        Zimbabwe     vermiculite
# 6476      1592    6619  2003        Zimbabwe     vermiculite
# 6477      1593    6620  2003  Western Sahara  phosphate rock
#
#                                                location  \
# 0                                 Gladstone, Queensland
# 1                   Nhulunbuy, Gove, Northern Territory
# 2     20 kilometers northwest of Collie, Western Aus...
# ...

# %%
#each company's output by mineral
df['country'].unique()
# Out:
# array(['Australia', 'Bangladesh', 'Bhutan', 'Brunei', 'Burma', 'Cambodia',
#        'China', 'Fiji', 'India', 'Indonesia', 'Japan', 'Laos', 'Malaysia',
#        'Mongolia', 'Nepal', 'New Caledonia', 'New Zealand', 'North Korea',
#        'Pakistan', 'Papua New Guinea', 'Philippines', 'Republic of Korea',
#        'Singapore', 'Sri Lanka', 'Taiwan', 'Thailand', 'Vietnam',
#        'Armenia', 'Azerbaijan', 'Belarus', 'Georgia', 'Kazakhstan',
#        'Kyrgyzstan', 'Moldova', 'Russia', 'Tajikistan', 'Turkmenistan',
#        'Ukraine', 'Uzbekistan', 'Albania', 'Austria', 'Belgium',
#        'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Cyprus',
#        'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy',
#        'Latvia', 'Lithuania', 'Luxembourg', 'Macedonia', 'Montenegro',
#        'Netherlands', 'Norway', 'Poland', 'Portugal', 'Romania', 'Serbia',
# ...

# %%
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup as bs
from webdriver_manager.chrome import ChromeDriverManager
from io import StringIO
from html.parser import HTMLParser
import sys

# %%
#set up browser
def init_browser():
    executable_path = {"executable_path": ChromeDriverManager().install()}
    return Browser("chrome", **executable_path, headless=False)
#scrape function
df_stocks =[]
tickers = []
def scrape():
    for company in df['maininvest'].dropna().str.replace(" ", "+"):
        print(f"company = {company}")
        if company == 'NaN' :
            next 
        else:
            url =(f'https://www.gurufocus.com/symbollookup1.php?company={company}')
            try:
                for page_table in pd.read_html(url):
                    df_stocks.append(page_table)
                    print(page_table)
            except:
                print("\t", sys.exc_info()[0])         
   # tickers = pd.concat(df_stocks)
scrape()
# Out:
# company = Rio+Tinto+Alcan+
#                             0
# 0  Please Input Company Name:
#                             0   1
# 0  Please Input Company Name: NaN
# 1                         NaN NaN
# company = Rio+Tinto++
#                             0
# 0  Please Input Company Name:
#                             0   1
# 0  Please Input Company Name: NaN
# 1                         NaN NaN
#         Ticker        Company                          Industry
# 0      BUE:RIO  Rio Tinto PLC  Other Industrial Metals & Mining
# 1      ASX:RIO  Rio Tinto Ltd  Other Industrial Metals & Mining
# 2    XBRU:RIOS  Rio Tinto PLC  Other Industrial Metals & Mining
# 3   BSP:RIOT34  Rio Tinto PLC  Other Industrial Metals & Mining
# 4     XSWX:RIO  Rio Tinto Ltd  Other Industrial Metals & Mining
# 5    XSWX:RIOP  Rio Tinto PLC  Other Industrial Metals & Mining
# 6     FRA:CRA1  Rio Tinto Ltd  Other Industrial Metals & Mining
# 7     FRA:RIO1  Rio Tinto PLC  Other Industrial Metals & Mining
# ...

# %%
shoes = df_stocks.copy

# %%
tickers = pd.concat(df_stocks)

# %%
tickers=tickers.drop_duplicates()

# %%
tickers
# Out:
#                              0   1             Company   Industry  \
# 0   Please Input Company Name: NaN                 NaN        NaN
# 0   Please Input Company Name: NaN                 NaN        NaN
# 1                          NaN NaN                 NaN        NaN
# 0   Please Input Company Name: NaN                 NaN        NaN
# 0   Please Input Company Name: NaN                 NaN        NaN
# ..                         ...  ..                 ...        ...
# 0   Please Input Company Name: NaN                 NaN        NaN
# 1                          NaN NaN                 NaN        NaN
# 0                          NaN NaN  Tata Chemicals Ltd  Chemicals
# 1                          NaN NaN  Tata Chemicals Ltd  Chemicals
# 2                          NaN NaN  Tata Chemicals Ltd  Chemicals
#
#           Ticker
# 0            NaN
# 0            NaN
# 1            NaN
# 0            NaN
# 0            NaN
# ..           ...
# 0            NaN
# 1            NaN
# ...

# %%
#create dictionary of single company to ticker
ticks = []
tic_only= tickers.copy()
tic_only =tic_only['Ticker'].to_list
ticks.append(tic_only)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-276-d6a2f467de39> in <module>
#       2 ticks = []
#       3 tic_only= tickers.copy()
# ----> 4 tic_only =tic_only['Ticker'].to_list
#       5 ticks.append(tic_only)
#
# TypeError: list indices must be integers or slices, not str

# %%
tickers
# Out:
# []

# %%
#passing our stock symbol to YFinance API
holders={}
company =[]
for ticker in tickers['Ticker']:

    ticker =ticker.split(':')
    print(ticker[1])
    tick=yf.Ticker(ticker[1])
    
    
    
    #
    holder=tick.institutional_holders
        
    
#     if holder is not None:
    holders.setdefault('holder',[]).append(holder)
    holders.setDefalt('ticker',[]).append(ticker)
    print(holders)
        
#     else:
#         next
# Out:
# RIO
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-fb603e8f8ac3> in <module>
#      16 #     if holder is not None:
#      17     holders.setdefault('holder',[]).append(holder)
# ---> 18     holders.setDefalt('ticker',[]).append(ticker)
#      19     print(holders)
#      20
#
# AttributeError: 'dict' object has no attribute 'setDefalt'

# %%
print(type(holders['holder'][1]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = holders['holder'][1].copy()

# %%
main_df = holders.copy()

# %%
main_df
# Out:
# {'holder': [                                      Holder    Shares Date Reported   % Out  \
#   0               Fisher Asset Management, LLC  12165772    2020-12-30  0.0098
#   1  State Farm Mutual Automobile Insurance Co  12132020    2020-12-30  0.0097
#   2                   Franklin Resources, Inc.  10511419    2020-12-30  0.0084
#   3   Arrowstreet Capital, Limited Partnership   6328480    2020-12-30  0.0051
#   4                  Goldman Sachs Group, Inc.   5303810    2020-12-30  0.0043
#   5               Dimensional Fund Advisors LP   3141974    2020-12-30  0.0025
#   6                        Harding Loevner LLC   2755692    2020-12-30  0.0022
#   7            Capital International Investors   2686989    2020-12-30  0.0022
#   8                Neuberger Berman Group, LLC   1922463    2020-12-30  0.0015
#   9                       Earnest Partners LLC   1773479    2020-12-30  0.0014
#
#          Value
#   0  915109369
#   1  912570544
#   2  790668937
#   3  476028265
# ...

# %%
holderList= main_df['holder']

# %%
holderList
# Out:
# [                                      Holder    Shares Date Reported   % Out  \
#  0               Fisher Asset Management, LLC  12165772    2020-12-30  0.0098
#  1  State Farm Mutual Automobile Insurance Co  12132020    2020-12-30  0.0097
#  2                   Franklin Resources, Inc.  10511419    2020-12-30  0.0084
#  3   Arrowstreet Capital, Limited Partnership   6328480    2020-12-30  0.0051
#  4                  Goldman Sachs Group, Inc.   5303810    2020-12-30  0.0043
#  5               Dimensional Fund Advisors LP   3141974    2020-12-30  0.0025
#  6                        Harding Loevner LLC   2755692    2020-12-30  0.0022
#  7            Capital International Investors   2686989    2020-12-30  0.0022
#  8                Neuberger Berman Group, LLC   1922463    2020-12-30  0.0015
#  9                       Earnest Partners LLC   1773479    2020-12-30  0.0014
#
#         Value
#  0  915109369
#  1  912570544
#  2  790668937
#  3  476028265
#  4  398952588
#  5  236339284
# ...

# %%
main_df['Holders'].holderList

# %%
tic_cop.to_csv(r'/Users/petebaker/Desktop/tic_cop.csv')

# %%
mainHolders_df=main_df.copy

# %%
tic_cop =tickers.copy()

# %%
tic_cop['Holders'] = holderList

# %%
tic_cop
# Out:
#                              Company                          Industry  \
# 0                      Rio Tinto PLC  Other Industrial Metals & Mining
# 1                      Rio Tinto Ltd  Other Industrial Metals & Mining
# 2                      Rio Tinto PLC  Other Industrial Metals & Mining
# 3                      Rio Tinto PLC  Other Industrial Metals & Mining
# 4                      Rio Tinto Ltd  Other Industrial Metals & Mining
# ..                               ...                               ...
# 746  Advanced Metallurgical Group NV  Other Industrial Metals & Mining
# 747  Advanced Metallurgical Group NV  Other Industrial Metals & Mining
# 748               Tata Chemicals Ltd                         Chemicals
# 749               Tata Chemicals Ltd                         Chemicals
# 750               Tata Chemicals Ltd                         Chemicals
#
#            Ticker                                            Holders
# ...

# %%
tic_cop
# Out:
#                              Company                          Industry  \
# 0                      Rio Tinto PLC  Other Industrial Metals & Mining
# 1                      Rio Tinto Ltd  Other Industrial Metals & Mining
# 2                      Rio Tinto PLC  Other Industrial Metals & Mining
# 3                      Rio Tinto PLC  Other Industrial Metals & Mining
# 4                      Rio Tinto Ltd  Other Industrial Metals & Mining
# ..                               ...                               ...
# 746  Advanced Metallurgical Group NV  Other Industrial Metals & Mining
# 747  Advanced Metallurgical Group NV  Other Industrial Metals & Mining
# 748               Tata Chemicals Ltd                         Chemicals
# 749               Tata Chemicals Ltd                         Chemicals
# 750               Tata Chemicals Ltd                         Chemicals
#
#            Ticker                                            Holders
# ...

# %%
mineral_list = []
for mineral in df['commodity']:
    mineral = mineral.lower()
    mineral_list.append(mineral)

# %%
mineral_list
# Out:
# ['alumina',
#  'alumina',
#  'alumina',
#  'alumina',
#  'alumina',
#  'alumina',
#  'aluminum',
#  'aluminum',
#  'aluminum',
#  'aluminum',
#  'aluminum',
#  'aluminum',
#  'aluminum',
#  'antimony',
#  'antimony',
#  'bauxite',
#  'bauxite',
#  'bauxite',
#  'bauxite',
#  'bauxite',
#  'bentonite',
#  'bentonite',
#  'bentonite',
#  'bentonite',
#  'cement',
#  'cement',
#  'cement',
#  'cement',
#  'cement',
#  'cement',
#  'cement',
#  'cement',
#  'cement',
#  'cement',
#  'cement',
#  'cement',
#  'chromite',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
#  'coal: black',
# ...

# %%
investors = df['maininvest'].str.replace(',', '')\
.str.replace('.', '')\
.str.replace('\d+', '')\
.str.replace("%","")\
.str.replace(";","")\
.str.replace("Ltd","")\
.str.replace("plc","")\
.str.replace("pty","")\
.str.replace("pty","")

# %%
nested_df = [{mineral:{investor{stock}}} for (mineral,investor, stock) in zip(mineral_list, investors)]

# %%
nested_df
# Out:
# [{'alumina': {'Rio Tinto Alcan '}},
#  {'alumina': {'Rio Tinto  '}},
#  {'alumina': {'BHP Billiton  '}},
#  {'alumina': {'Alcoa World Alumina Australia '}},
#  {'alumina': {'Alcoa World Alumina Australia '}},
#  {'alumina': {'Alcoa World Alumina Australia '}},
#  {'aluminum': {'Rio Tinto Alcan Inc '}},
#  {'aluminum': {'Rio Tinto Alcan Inc '}},
#  {'aluminum': {'Rio Tinto Alcan Inc '}},
#  {'aluminum': {'Alcoa of Australia '}},
#  {'aluminum': {'Alcoa of Australia '}},
#  {'aluminum': {'Hydro Aluminum Kurri Kurri Pty  '}},
#  {'aluminum': {'Rio Tinto Alcan Inc '}},
#  {'antimony': {'Straits Resources  '}},
#  {'antimony': {'Cambrian Mining Plc '}},
#  {'bauxite': {'Alcoa World Alumina Australia '}},
#  {'bauxite': {'Rio Tinto  '}},
#  {'bauxite': {'BHP Billiton  '}},
#  {'bauxite': {'Rio Tinto  '}},
#  {'bauxite': {'Rio Tinto Alcan Inc '}},
#  {'bentonite': {'Unimin Australia  '}},
#  {'bentonite': {'PCP Douglas Pty  '}},
#  {'bentonite': {'Unimin Australia  '}},
# ...

# %%
tickers = tickers.drop(columns=[0,1])

# %%
tickers = tickers.dropna()

# %%
tickers =tickers.reset_index()

# %% [raw]
# tickers =tickers.drop(columns =['index'])

# %%
stock = []
for tick in tickers:
    tick = ticker.replace(':')
    print(tick)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-311-80816545a85a> in <module>
#       1 stock = []
#       2 for tick in tickers:
# ----> 3     tick = ticker.replace(':')
#       4     print(tick)
#
# AttributeError: 'list' object has no attribute 'replace'
